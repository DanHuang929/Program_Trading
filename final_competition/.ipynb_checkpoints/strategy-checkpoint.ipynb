# %%
import shioaji as sj

api = sj.Shioaji(simulation=True)
accounts = api.login(
    api_key="3WmNiNGCQMuPGsRMdpgML3MWYkqM1gExzPUGKKcjhufd",     # 請修改此處
    secret_key="EnKAve1Ldd8wuerMRcwKUUrB4DRmLyoxCSyoApmbzrTM"   
)
# Out:
# Response Code: 0 | Event Code: 0 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up

# %%
# import datetime
# import pandas as pd
# import os
# import numpy as np

# days = 374

# kbars = api.kbars(
#     contract=api.Contracts.Futures.TXF.TXFR1, 
#     start=(datetime.datetime.now() - datetime.timedelta(days=days)).strftime("%Y-%m-%d"), 
#     end=datetime.datetime.now().strftime("%Y-%m-%d"),
# )

# df = pd.DataFrame({**kbars})
# df.ts = pd.to_datetime(df.ts)
# df = df.set_index('ts')
# df.index.name = None
# df_1min = df

# df_1min = df_1min[['Open', 'High', 'Low', 'Close', 'Volume']]
# df_1min.to_csv('TXF_1min.csv')

# %% [markdown]
# 使用5分K，日盤資料

# %%
import pandas as pd


df = pd.read_csv(f"TXF_1min.csv", index_col=0)

df.index = pd.to_datetime(df.index)
df= df.between_time('08:44:00', '13:45:01')
df_resample = df.resample('5T', label='right', closed='right').agg(
    {'Open'  :'first',
     'High'  :'max',
     'Low'   :'min',
     'Close' :'last',
     'Volume':'sum'
    })
df_resample.dropna(axis=0, inplace=True)
df = df_resample
print(df.head())
print(df.tail())
# Out:
#                         Open     High      Low    Close  Volume
# 2022-05-09 08:50:00  16156.0  16194.0  16152.0  16184.0    5189
# 2022-05-09 08:55:00  16184.0  16188.0  16166.0  16169.0    2025
# 2022-05-09 09:00:00  16169.0  16173.0  16139.0  16144.0    2741
# 2022-05-09 09:05:00  16144.0  16183.0  16111.0  16111.0    6842
# 2022-05-09 09:10:00  16111.0  16146.0  16105.0  16115.0    4559
#                         Open     High      Low    Close  Volume
# 2023-05-08 13:25:00  15714.0  15722.0  15704.0  15722.0    1482
# 2023-05-08 13:30:00  15722.0  15726.0  15714.0  15723.0    1197
# 2023-05-08 13:35:00  15723.0  15726.0  15718.0  15723.0    1077
# 2023-05-08 13:40:00  15723.0  15724.0  15718.0  15720.0     694
# 2023-05-08 13:45:00  15720.0  15725.0  15718.0  15723.0    1184

# %% [markdown]
# 策略部分
#
# # 策略(5分K)
#
# **使用威廉指標與SMA指標當作技術指標**
#
# 多單策略：
#
# 進場：
# * WR向上超越超買區(-30)
# * SMA黃金交叉
# * 開盤15分鐘後進場
#
# 出場：
# * 百分比停損 0.1%
# * 跌破3根低點停利停損
# * WR跌出超買區
# * SMA死亡交叉
# * 13.30平倉
#
#
# 空單策略：
#
# 進場：
# * WR向下超越超賣區(-75)
# * SMA死亡交叉
# * 開盤15分鐘後進場
#
# 出場：
# * 百分比停損 0.1%
# * 超出3根高點停利停損
# * WR向上超出超賣區
# * SMA黃金交叉
# * 13.30平倉

# %%
from backtesting import Strategy
from backtesting.lib import crossover
import talib as ta

from datetime import time

#使用威廉指標當作技術指標
class WL(Strategy): 

    WL = 65
    OB = -15
    stop_pct = 1 #表示0.x%
    OS = -80
    L = 2
    
    n1 = 15
    n2 = 55
    
    fast_period = 12
    slow_period = 26
    signal_period = 9
    proportion = 0.9

    def init(self):
        self.wl = self.I(ta.WILLR, self.data.High, self.data.Low, self.data.Close, self.WL)
        self.macd = self.I(ta.MACD, self.data.Close, fastperiod=self.fast_period, slowperiod=self.slow_period, signalperiod=self.signal_period)
        self.min = self.I(ta.MIN, self.data.Low, self.L)
        self.max = self.I(ta.MAX, self.data.High, self.L)
        self.proportion = 0.9
        
        self.sma1 = self.I(ta.SMA, self.data.Close, self.n1) # sma 快線
        self.sma2 = self.I(ta.SMA, self.data.Close, self.n2) # sma 慢線

    def next(self):
                
        curr_macd = self.macd[2][-1]
        prev_macd = self.macd[2][-2]

        macd_now = self.macd[0][-1]
        signal_now = self.macd[1][-1]

        signal = 0
        # MACD crosses the zero line from below - buy signal
        if prev_macd < 0 and curr_macd > 0:
            signal = 1
        
        # MACD crosses the zero line from above - sell signal
        elif prev_macd > 0 and curr_macd < 0:
            signal = -1

        long_condition1 = (self.wl[-2] < self.OB) and (self.wl > self.OB) # WR多單進場
        long_condition2 = self.wl[-2] > self.OB and self.wl < self.OB #WR跌出超買區
        long_condition3 = self.data.Close[-1] <= self.min #跌破3根低點停利停損
        long_condition4 = self.position.pl_pct < -(self.stop_pct * 0.001) #百分比停損
        long_condition5 = crossover(self.sma1 , self.sma2) #sma 快線 cross over sma 慢線 -> buy
        long_condition6 = crossover(self.sma2 , self.sma1) #sma 慢線 cross over sma 快線 -> sell
        
        
        
        if (self.data.index[-1].time() < time(13, 30)) and (self.data.index[-1].time() > time(9, 0)) and (not self.position.is_long): # 多單
            if long_condition1 or long_condition5: # 多單進場
                self.buy(size=200)
        if self.position.is_long: # 多單出場
            if long_condition2: #WR跌出超買區
                self.position.close()
            elif long_condition3: #跌破3根低點停利停損
                self.position.close()
            elif long_condition4: #百分比停損
                self.position.close()
            elif long_condition6:
                self.position.close()
                
                
        short_condition1 = (self.wl[-2] > self.OS) and (self.wl < self.OS)# WR空單進場
        short_condition2 = self.wl[-2] < self.OS and self.wl > self.OS #WR向上超出超賣區
        short_condition3 = self.data.Close[-1] >= self.max #超出3根高點停利停損
        short_condition4 = self.position.pl_pct < -(self.stop_pct * 0.001) #百分比停損
        short_condition5 = crossover(self.sma1 , self.sma2) #sma 快線 cross over sma 慢線 -> sell
        short_condition6 = crossover(self.sma2 , self.sma1) #sma 慢線 cross over sma 快線 -> buy
                
        if (self.data.index[-1].time() < time(13, 30)) and (self.data.index[-1].time() > time(9, 0)) and (not self.position.is_short): # 空單
            if short_condition1 or short_condition6: # 空單進場
                self.sell(size=200)
        if self.position.is_short: # 空單出場
            if short_condition2: #WR向上超出超賣區
                self.position.close()
            elif short_condition3: #超出3根高點停利停損
                self.position.close()
            elif short_condition4: #百分比停損
                self.position.close()
            elif short_condition5:
                self.position.close()
        
        if self.data.index[-1].time() >= time(13, 30) and (self.position.is_long or self.position.is_short): #平倉
                self.position.close()

# %% [markdown]
# 回測部分(包含樣本內外)

# %%
from backtesting import Backtest
df_all = df[df.index >= '2022-05-022']
df_all = df[df.index <= '2023-05-022']
df_in_sample = df_all[df_all.index <= '2023-05-22']
df_out_sample = df_all[df_all.index >= '2023-05-22']

# %%
bt = Backtest(df_all, WL, cash=500_000, commission=0.000033, hedging=False, exclusive_orders=False, margin=0.05)
stats = bt.run()
print(stats)
# bt.plot(resample=False)
# Out:
# Start                     2022-05-09 08:50:00
# End                       2023-05-05 13:45:00
# Duration                    361 days 04:55:00
# Exposure Time [%]                   35.585399
# Equity Final [$]                  868460.0496
# Equity Peak [$]                   884023.0276
# Return [%]                           73.69201
# Buy & Hold Return [%]               -3.342808
# Return (Ann.) [%]                   77.700274
# Volatility (Ann.) [%]               46.971525
# Sharpe Ratio                           1.6542
# Sortino Ratio                        6.092193
# Calmar Ratio                         7.895091
# Max. Drawdown [%]                   -9.841593
# Avg. Drawdown [%]                     -1.3874
# Max. Drawdown Duration      118 days 03:00:00
# Avg. Drawdown Duration        3 days 11:41:00
# # Trades                                  700
# Win Rate [%]                        34.142857
# Best Trade [%]                       1.691788
# Worst Trade [%]                     -0.634784
# Avg. Trade [%]                       0.017244
# Max. Trade Duration           0 days 04:05:00
# Avg. Trade Duration           0 days 00:32:00
# Profit Factor                        1.273941
# Expectancy [%]                       0.017538
# SQN                                  1.959033
# _strategy                                  WL
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
from matplotlib.ticker import StrMethodFormatter
from backtesting.lib import _EQUITY_AGG

equity_data = stats._equity_curve.resample('1D', label='right').agg(_EQUITY_AGG).dropna(how='all')
equity_data['DrawdownPct'] = equity_data['DrawdownPct'].multiply(-100)

f, (ax1, ax2) = plt.subplots(2, sharex=True, figsize=(19.2, 10.8), gridspec_kw={'height_ratios': [5, 2]})

ax1.grid(linestyle = '--', linewidth = 1)
ax1.plot(equity_data['Equity'])
ax1.set(ylabel="Equity($)")
ax1.yaxis.set_major_formatter(StrMethodFormatter('${x:,.0f}'))
date_form = DateFormatter("%Y-%m-%d")
ax1.xaxis.set_major_formatter(date_form)
ax1.xaxis.set_major_locator(mdates.DayLocator(interval=10))
ax2.grid(linestyle = '--', linewidth = 1)
ax2.plot(equity_data['DrawdownPct'], color="red")
ax2.set(ylabel="DrawdownPct(%)")
ax2.fill_between(equity_data['DrawdownPct'].index, equity_data['DrawdownPct'], where=(equity_data['DrawdownPct'] <= 0), color="red")   
f.subplots_adjust(hspace=0)
f.autofmt_xdate()

plt.show()
# Out:
# SDK NOTICE Thu May 18 11:47:48.496 2023 solClient.c:12194                    (30e7db000) Session '(c1,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 172.20.10.2:65215'
# SDK NOTICE Thu May 18 11:47:48.506 2023 solClientOS.c:4470                   (30e7db000) TCP connection failure for fd 88, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:47:48.506 2023 solClient.c:6147                     (30e7db000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:47:48.506 2023 solClient.c:11240                    (30e7db000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65396'
# SDK NOTICE Thu May 18 11:47:48.506 2023 solClient.c:11395                    (30e7db000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65396'
# Response Code: 0 | Event Code: 12 | Info: solClient.c:12194                    (30e7db000) Session '(c1,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203. | Event: Session reconnecting
# SDK NOTICE Thu May 18 11:47:49.018 2023 solClient.c:12194                    (30e5cf000) Session '(c0,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 172.20.10.2:65213'
# SDK NOTICE Thu May 18 11:47:49.020 2023 solClientOS.c:4470                   (30e5cf000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:47:49.020 2023 solClient.c:6147                     (30e5cf000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:47:49.020 2023 solClient.c:11240                    (30e5cf000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65397'
# SDK NOTICE Thu May 18 11:47:49.020 2023 solClient.c:11395                    (30e5cf000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65397'
# Response Code: 0 | Event Code: 12 | Info: solClient.c:12194                    (30e5cf000) Session '(c0,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203. | Event: Session reconnecting
# Response Code: 0 | Event Code: 13 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total reconnection attempt 2 of 10) | Event: Session reconnected
# Response Code: 0 | Event Code: 13 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total reconnection attempt 2 of 10) | Event: Session reconnected
# SDK NOTICE Thu May 18 11:48:34.390 2023 solClient.c:12194                    (30e7db000) Session '(c1,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 172.16.5.73:65424'
# Response Code: 0 | Event Code: 12 | Info: solClient.c:12194                    (30e7db000) Session '(c1,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203. | Event: Session reconnecting
# SDK NOTICE Thu May 18 11:48:34.993 2023 solClient.c:12194                    (30e5cf000) Session '(c0,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 172.16.5.73:65425'
# Response Code: 0 | Event Code: 12 | Info: solClient.c:12194                    (30e5cf000) Session '(c0,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203. | Event: Session reconnecting
# SDK NOTICE Thu May 18 11:48:37.468 2023 solClient.c:12123                    (30e7db000) Connect attempt for host '203.66.91.161:80' for session '(c1,s1)_sinopac(client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 172.16.5.73:65428')' timed out
# SDK NOTICE Thu May 18 11:48:38.045 2023 solClient.c:12123                    (30e5cf000) Connect attempt for host '203.66.91.161:80' for session '(c0,s1)_sinopac(client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 172.16.5.73:65430')' timed out
# SDK NOTICE Thu May 18 11:48:40.516 2023 solClientOS.c:4470                   (30e7db000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:48:40.516 2023 solClient.c:6147                     (30e7db000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:48:40.516 2023 solClient.c:11240                    (30e7db000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65445'
# SDK NOTICE Thu May 18 11:48:40.516 2023 solClient.c:11395                    (30e7db000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65445'
# SDK NOTICE Thu May 18 11:48:41.101 2023 solClientOS.c:4470                   (30e5cf000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:48:41.101 2023 solClient.c:6147                     (30e5cf000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:48:41.101 2023 solClient.c:11240                    (30e5cf000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65446'
# SDK NOTICE Thu May 18 11:48:41.101 2023 solClient.c:11395                    (30e5cf000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65446'
# Response Code: 0 | Event Code: 13 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total reconnection attempt 3 of 10) | Event: Session reconnected
# Response Code: 0 | Event Code: 13 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total reconnection attempt 3 of 10) | Event: Session reconnected
# SDK NOTICE Thu May 18 11:52:15.036 2023 solClient.c:12194                    (30e5cf000) Session '(c0,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 172.16.5.73:65464'
# SDK NOTICE Thu May 18 11:52:15.089 2023 solClient.c:12194                    (30e7db000) Session '(c1,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 172.16.5.73:65463'
# Response Code: 0 | Event Code: 12 | Info: solClient.c:12194                    (30e5cf000) Session '(c0,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203. | Event: Session reconnecting
# Response Code: 0 | Event Code: 12 | Info: solClient.c:12194                    (30e7db000) Session '(c1,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203. | Event: Session reconnecting
# SDK NOTICE Thu May 18 11:52:18.045 2023 solClient.c:12123                    (30e5cf000) Connect attempt for host '203.66.91.161:80' for session '(c0,s1)_sinopac(client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 172.16.5.73:65498')' timed out
# SDK NOTICE Thu May 18 11:52:18.165 2023 solClient.c:12123                    (30e7db000) Connect attempt for host '203.66.91.161:80' for session '(c1,s1)_sinopac(client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 172.16.5.73:65499')' timed out
# SDK NOTICE Thu May 18 11:52:21.129 2023 solClientOS.c:4470                   (30e5cf000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:21.129 2023 solClient.c:6147                     (30e5cf000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:21.129 2023 solClient.c:11240                    (30e5cf000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65516'
# SDK NOTICE Thu May 18 11:52:21.129 2023 solClient.c:11395                    (30e5cf000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65516'
# SDK NOTICE Thu May 18 11:52:21.236 2023 solClientOS.c:4470                   (30e7db000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:21.236 2023 solClient.c:6147                     (30e7db000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:21.236 2023 solClient.c:11240                    (30e7db000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65517'
# SDK NOTICE Thu May 18 11:52:21.236 2023 solClient.c:11395                    (30e7db000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65517'
# SDK NOTICE Thu May 18 11:52:24.144 2023 solClientOS.c:4470                   (30e5cf000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:24.144 2023 solClient.c:6147                     (30e5cf000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:24.144 2023 solClient.c:11240                    (30e5cf000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65518'
# SDK NOTICE Thu May 18 11:52:24.144 2023 solClient.c:11395                    (30e5cf000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65518'
# SDK NOTICE Thu May 18 11:52:24.272 2023 solClientOS.c:4470                   (30e7db000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:24.272 2023 solClient.c:6147                     (30e7db000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:24.272 2023 solClient.c:11240                    (30e7db000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65519'
# SDK NOTICE Thu May 18 11:52:24.272 2023 solClient.c:11395                    (30e7db000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65519'
# SDK NOTICE Thu May 18 11:52:27.208 2023 solClientOS.c:4470                   (30e5cf000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:27.208 2023 solClient.c:6147                     (30e5cf000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:27.209 2023 solClient.c:11240                    (30e5cf000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65520'
# SDK NOTICE Thu May 18 11:52:27.209 2023 solClient.c:11395                    (30e5cf000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65520'
# SDK NOTICE Thu May 18 11:52:27.343 2023 solClientOS.c:4470                   (30e7db000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:27.343 2023 solClient.c:6147                     (30e7db000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:27.343 2023 solClient.c:11240                    (30e7db000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65521'
# SDK NOTICE Thu May 18 11:52:27.343 2023 solClient.c:11395                    (30e7db000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65521'
# SDK NOTICE Thu May 18 11:52:30.259 2023 solClientOS.c:4470                   (30e5cf000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:30.259 2023 solClient.c:6147                     (30e5cf000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:30.259 2023 solClient.c:11240                    (30e5cf000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65523'
# SDK NOTICE Thu May 18 11:52:30.259 2023 solClient.c:11395                    (30e5cf000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65523'
# SDK NOTICE Thu May 18 11:52:30.393 2023 solClientOS.c:4470                   (30e7db000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:30.393 2023 solClient.c:6147                     (30e7db000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:30.393 2023 solClient.c:11240                    (30e7db000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65524'
# SDK NOTICE Thu May 18 11:52:30.393 2023 solClient.c:11395                    (30e7db000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65524'
# SDK NOTICE Thu May 18 11:52:33.317 2023 solClientOS.c:4470                   (30e5cf000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:33.318 2023 solClient.c:6147                     (30e5cf000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:33.318 2023 solClient.c:11240                    (30e5cf000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65525'
# SDK NOTICE Thu May 18 11:52:33.318 2023 solClient.c:11395                    (30e5cf000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65525'
# SDK NOTICE Thu May 18 11:52:33.444 2023 solClientOS.c:4470                   (30e7db000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:33.444 2023 solClient.c:6147                     (30e7db000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:33.444 2023 solClient.c:11240                    (30e7db000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65526'
# SDK NOTICE Thu May 18 11:52:33.444 2023 solClient.c:11395                    (30e7db000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:65526'
# SDK NOTICE Thu May 18 11:52:36.389 2023 solClientOS.c:4470                   (30e5cf000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:36.389 2023 solClient.c:6147                     (30e5cf000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:36.389 2023 solClient.c:11240                    (30e5cf000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49157'
# SDK NOTICE Thu May 18 11:52:36.389 2023 solClient.c:11395                    (30e5cf000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49157'
# SDK NOTICE Thu May 18 11:52:36.505 2023 solClientOS.c:4470                   (30e7db000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:36.505 2023 solClient.c:6147                     (30e7db000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:36.505 2023 solClient.c:11240                    (30e7db000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49158'
# SDK NOTICE Thu May 18 11:52:36.505 2023 solClient.c:11395                    (30e7db000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49158'
# SDK NOTICE Thu May 18 11:52:39.488 2023 solClientOS.c:4470                   (30e5cf000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:39.488 2023 solClient.c:6147                     (30e5cf000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:39.488 2023 solClient.c:11240                    (30e5cf000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49159'
# SDK NOTICE Thu May 18 11:52:39.488 2023 solClient.c:11395                    (30e5cf000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49159'
# SDK NOTICE Thu May 18 11:52:39.546 2023 solClientOS.c:4470                   (30e7db000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:39.546 2023 solClient.c:6147                     (30e7db000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:39.547 2023 solClient.c:11240                    (30e7db000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49160'
# SDK NOTICE Thu May 18 11:52:39.547 2023 solClient.c:11395                    (30e7db000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49160'
# SDK NOTICE Thu May 18 11:52:42.500 2023 solClientOS.c:4470                   (30e5cf000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:42.501 2023 solClient.c:6147                     (30e5cf000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:42.501 2023 solClient.c:11240                    (30e5cf000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49161'
# SDK NOTICE Thu May 18 11:52:42.501 2023 solClient.c:11395                    (30e5cf000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49161'
# SDK NOTICE Thu May 18 11:52:42.602 2023 solClientOS.c:4470                   (30e7db000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:42.602 2023 solClient.c:6147                     (30e7db000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:42.602 2023 solClient.c:11240                    (30e7db000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49162'
# SDK NOTICE Thu May 18 11:52:42.602 2023 solClient.c:11395                    (30e7db000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49162'
# SDK NOTICE Thu May 18 11:52:45.554 2023 solClientOS.c:4470                   (30e5cf000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:45.554 2023 solClient.c:6147                     (30e5cf000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:45.554 2023 solClient.c:11240                    (30e5cf000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49163'
# SDK NOTICE Thu May 18 11:52:45.554 2023 solClient.c:11395                    (30e5cf000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032420/436313/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49163'
# SDK NOTICE Thu May 18 11:52:45.659 2023 solClientOS.c:4470                   (30e7db000) TCP connection failure for fd 85, error = Network is unreachable (51)
# SDK NOTICE Thu May 18 11:52:45.659 2023 solClient.c:6147                     (30e7db000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Thu May 18 11:52:45.659 2023 solClient.c:11240                    (30e7db000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49164'
# SDK NOTICE Thu May 18 11:52:45.659 2023 solClient.c:11395                    (30e7db000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0518/032425/607752/42.72.204.182', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:49164'
# Session Down.
# Response Code: 0 | Event Code: 1 | Info: solClientOS.c:4470                   (30e5cf000) TCP connection failure for fd 85, error = Network is unreachable (51) | Event: Session down
# Session Down.
# Response Code: 0 | Event Code: 1 | Info: solClientOS.c:4470                   (30e7db000) TCP connection failure for fd 85, error = Network is unreachable (51) | Event: Session down

# %%
# bt = Backtest(df_in_sample, WL, cash=500_000, commission=0.000033, hedging=False, exclusive_orders=False, margin=0.05)
# stats = bt.optimize(
# #                     n1=range(5, 30, 5),
# #                     n2=range(20, 70, 5), 
#                     OB=range(-5, -35, -5),
#                     OS=range(-95, -65, 5),
# #                     stop_pct=range(1, 10, 2),
# #                     L=range(2,10,1),
#                     maximize='Equity Final [$]',
#                     ) # 快線週期<慢線週期
# print(stats.to_string())

# %% [markdown]
# ## out sample

# %%
bt = Backtest(df_out_sample, WL, cash=500_000, commission=0.000033, hedging=False, exclusive_orders=False, margin=0.05)
stats = bt.run()
print(stats)
equity_data = stats._equity_curve.resample('1D', label='right').agg(_EQUITY_AGG).dropna(how='all')
equity_data['DrawdownPct'] = equity_data['DrawdownPct'].multiply(-100)

f, (ax1, ax2) = plt.subplots(2, sharex=True, figsize=(19.2, 10.8), gridspec_kw={'height_ratios': [5, 2]})

ax1.grid(linestyle = '--', linewidth = 1)
ax1.plot(equity_data['Equity'])
ax1.set(ylabel="Equity($)")
ax1.yaxis.set_major_formatter(StrMethodFormatter('${x:,.0f}'))
date_form = DateFormatter("%Y-%m-%d")
ax1.xaxis.set_major_formatter(date_form)
ax1.xaxis.set_major_locator(mdates.DayLocator(interval=10))
ax2.grid(linestyle = '--', linewidth = 1)
ax2.plot(equity_data['DrawdownPct'], color="red")
ax2.set(ylabel="DrawdownPct(%)")
ax2.fill_between(equity_data['DrawdownPct'].index, equity_data['DrawdownPct'], where=(equity_data['DrawdownPct'] <= 0), color="red")   
f.subplots_adjust(hspace=0)
f.autofmt_xdate()

plt.show()
# Out:
# Start                     2022-12-26 08:50:00
# End                       2023-04-24 13:45:00
# Duration                    119 days 04:55:00
# Exposure Time [%]                   33.634259
# Equity Final [$]                  550644.2334
# Equity Peak [$]                   561788.2178
# Return [%]                          10.128847
# Buy & Hold Return [%]                9.874112
# Return (Ann.) [%]                   40.169595
# Volatility (Ann.) [%]               40.195911
# Sharpe Ratio                         0.999345
# Sortino Ratio                        2.706959
# Calmar Ratio                         4.270956
# Max. Drawdown [%]                   -9.405294
# Avg. Drawdown [%]                   -2.451594
# Max. Drawdown Duration       37 days 23:55:00
# Avg. Drawdown Duration        6 days 04:04:00
# # Trades                                  196
# Win Rate [%]                        35.714286
# Best Trade [%]                       0.790377
# Worst Trade [%]                     -0.312429
# Avg. Trade [%]                       0.008015
# Max. Trade Duration           0 days 03:30:00
# Avg. Trade Duration           0 days 00:33:00
# Profit Factor                        1.153947
# Expectancy [%]                       0.008166
# SQN                                  0.668934
# _strategy                                  WL
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

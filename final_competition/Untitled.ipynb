# %%
from collections import defaultdict, deque
from shioaji import BidAskFOPv1, Exchange
import shioaji as sj
import datetime
import pandas as pd
import talib as ta
import time
from math import ceil
import pytrader as pyt
from backtesting.lib import crossover
# Out:
# 2023-05-19 12:49:42.114 | WARNING  | importlib._bootstrap:_call_with_frames_removed:228 - Optional: pip install shioaji[speed] for better performance.
# /Users/yun_yang/opt/anaconda3/lib/python3.9/site-packages/backtesting/_plotting.py:50: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support (e.g. PyCharm, Spyder IDE). Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
api = sj.Shioaji(simulation=True)
accounts = api.login(
    api_key="3WmNiNGCQMuPGsRMdpgML3MWYkqM1gExzPUGKKcjhufd",     # 請修改此處
    secret_key="EnKAve1Ldd8wuerMRcwKUUrB4DRmLyoxCSyoApmbzrTM"   
)

# 輸入學號、API_KEY、SECRET_KEY
trader = pyt.pytrader(strategy='108062313', api_key="3WmNiNGCQMuPGsRMdpgML3MWYkqM1gExzPUGKKcjhufd", secret_key="EnKAve1Ldd8wuerMRcwKUUrB4DRmLyoxCSyoApmbzrTM") 
# # 設定商品
trader.contract('TXF')

contract = min(
    [
        x for x in api.Contracts.Futures.TXF
        if x.code[-2:] not in ["R1", "R2"]
    ],
    key=lambda x: x.delivery_date
)

msg_queue = defaultdict(deque)
api.set_context(msg_queue)


@api.on_bidask_fop_v1(bind=True)
def quote_callback(self, exchange: Exchange, bidask: BidAskFOPv1):
    # append quote to message queue
    self['bidask'].append(bidask)


api.quote.subscribe(
    contract,
    quote_type=sj.constant.QuoteType.BidAsk,
    version=sj.constant.QuoteVersion.v1
)

time.sleep(2.5)

# get maximum strategy kbars to dataframe, extra 30 it's for safety
bars = 65 + 30

# since every day has 60 kbars (only from 8:45 to 13:45), for 5 minuts kbars
days = ceil(bars/60)

df_5min = []
while(len(df_5min) < bars):
    kbars = api.kbars(
        contract=api.Contracts.Futures.TXF.TXFR1,
        start=(datetime.date.today() -
               datetime.timedelta(days=days)).strftime("%Y-%m-%d"),
        end=datetime.date.today().strftime("%Y-%m-%d"),
    )
    df = pd.DataFrame({**kbars})
    df.ts = pd.to_datetime(df.ts)
    df = df.set_index('ts')
    df.index.name = None
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
    df = df.between_time('08:44:00', '13:45:01')
    df_5min = df.resample('5T', label='right', closed='right').agg(
        {'Open': 'first',
            'High': 'max',
            'Low': 'min',
            'Close': 'last',
            'Volume': 'sum'
         })
    df_5min.dropna(axis=0, inplace=True)
    days += 1

ts = datetime.datetime.now()
# Out:
# Response Code: 0 | Event Code: 0 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up
# Response Code: 0 | Event Code: 0 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up
# Response Code: 200 | Event Code: 16 | Info: QUO/v1/FOP/*/TFE/TXFF3 | Event: Subscribe or Unsubscribe ok
# Response Code: 200 | Event Code: 16 | Info: QUO/v1/FOP/*/TFE/TXFF3 | Event: Subscribe or Unsubscribe ok

# %%
while datetime.datetime.now().time() < datetime.time(13, 40):

    # this place can add stop or limit order
    if(len(trader.position) == 0):
        self_position = 'None'
    else:
        self_position = 'Buy' if trader.position['is_long'] else 'Sell'
    
    if self_position == 'Buy':    
        if trader.position['pnl'] < -200 * 50: # 50 point stop loss
            trader.sell(size = 1)
    if self_position == 'Sell':    
        if trader.position['pnl'] < -200 * 50: # 50 point stop loss
            trader.buy(size = 1)

    # local time > next kbars time
    if(datetime.datetime.now() >= ts):

        kbars = api.kbars(
            contract=api.Contracts.Futures.TXF.TXFR1,
            start=datetime.date.today().strftime("%Y-%m-%d"),
            end=datetime.date.today().strftime("%Y-%m-%d"),
        )
        df = pd.DataFrame({**kbars})
        df.ts = pd.to_datetime(df.ts)
        df = df.set_index('ts')
        df.index.name = None
        df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
        df = df.between_time('08:44:00', '13:45:01')
        df = df.resample('5T', label='right', closed='right').agg({
            'Open': 'first',
            'High': 'max',
            'Low': 'min',
            'Close': 'last',
            'Volume': 'sum'})
        df.dropna(axis=0, inplace=True)
        df_5min.update(df)
        to_be_added = df.loc[df.index.difference(df_5min.index)]
        df_5min = pd.concat([df_5min, to_be_added])
        ts = df_5min.iloc[-1].name.to_pydatetime()

        # next kbar time update and local time < next kbar time
        if (datetime.datetime.now().minute != ts.minute):

            df_5min = df_5min[:-1]

            WL = 65
            OB = -15
            OS = -80
            L = 3
            
            n1 = 15
            n2 = 55

            self_wl = ta.WILLR(
                df_5min['High'], df_5min['Low'], df_5min['Close'], WL)
            self_min = ta.MIN(df_5min['Low'], L)
            self_max = ta.MAX(df_5min['High'], L)
            self_sma1 = ta.SMA(df_5min['Close'], n1) # sma 快線
            self_sma2 = ta.SMA(df_5min['Close'], n2) # sma 慢線
            
            condition1 = datetime.datetime.now().time() < datetime.time(13, 25)
            condition2 = datetime.datetime.now().time() > datetime.time(9, 0)

#             condition1 = datetime.datetime.now().time() < time(13, 25)
#             condition2 = datetime.datetime.now().time() > time(9, 0)
#             condition3 = (self_wl[-2] < OB) and (self_wl[-1] > OB)
#             condition4 = (self_wl[-2] > OB) and (self_wl[-1] < OB)
#             condition5 = df_5min['Close'][-1] <= self_min[-1]
#             condition6 = datetime.datetime.now().time() >= time(13, 25)
            
            long_condition1 = (self_wl[-2] < OB) and (self_wl[-1] > OB) # WR多單進場
            long_condition2 = self_wl[-2] > OB and self_wl[-1] < OB #WR跌出超買區
            long_condition3 = df_5min['Close'][-1] <= self_min[-1] #跌破3根低點停利停損
#             long_condition4 = self.position.pl_pct < -(self.stop_pct * 0.001) #百分比停損
            long_condition5 = crossover(self_sma1 , self_sma2) #sma 快線 cross over sma 慢線 -> buy
            long_condition6 = crossover(self_sma2 , self_sma1) #sma 慢線 cross over sma 快線 -> sell
            
            if(len(trader.position) == 0):
                self_position = 'None'
            else:
                self_position = 'Buy' if trader.position['is_long'] else 'Sell'
            

            if self_position == 'None':
                if condition1 and condition2:
                    if long_condition1 or long_condition5:
                        trader.buy(size = 1)

            elif self_position == 'Buy':
                if long_condition2 or long_condition3 or long_condition6:
                    trader.sell(size = 1)           
                    
#           ============================

            short_condition1 = (self_wl[-2] > OS) and (self_wl[-1] < OS)# WR空單進場
            short_condition2 = self_wl[-2] < OS and self_wl[-1] > OS #WR向上超出超賣區
            short_condition3 = df_5min['Close'][-1] >= self_max #超出3根高點停利停損
#             short_condition4 = self.position.pl_pct < -(self.stop_pct * 0.001) #百分比停損
            short_condition5 = crossover(self_sma1 , self_sma2) #sma 快線 cross over sma 慢線 -> sell
            short_condition6 = crossover(self_sma2 , self_sma1) #sma 慢線 cross over sma 快線 -> buy
            
            if self_position == 'None':
                if condition1 and condition2:
                    if short_condition1 or short_condition6:
                        trader.sell(size = 1)

            elif self_position == 'Sell':
                if short_condition2 or short_condition3 or short_condition5:
                    trader.buy(size = 1)


api.quote.unsubscribe(
    contract,
    quote_type=sj.constant.QuoteType.BidAsk,
    version=sj.constant.QuoteVersion.v1
)

api.logout()
# Out:
# SDK NOTICE Fri May 19 13:06:50.071 2023 solClient.c:12194                    (3128e0000) Session '(c1,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 172.20.10.2:51445'
# SDK NOTICE Fri May 19 13:06:50.072 2023 solClientOS.c:4470                   (3128e0000) TCP connection failure for fd 87, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:06:50.072 2023 solClient.c:6147                     (3128e0000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:06:50.072 2023 solClient.c:11240                    (3128e0000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51451'
# SDK NOTICE Fri May 19 13:06:50.072 2023 solClient.c:11395                    (3128e0000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51451'
# Response Code: 0 | Event Code: 12 | Info: solClient.c:12194                    (3128e0000) Session '(c1,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.6 | Event: Session reconnecting
# SDK NOTICE Fri May 19 13:06:50.914 2023 solClient.c:12194                    (3126d4000) Session '(c0,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 172.20.10.2:51443'
# SDK NOTICE Fri May 19 13:06:50.915 2023 solClientOS.c:4470                   (3126d4000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:06:50.915 2023 solClient.c:6147                     (3126d4000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:06:50.915 2023 solClient.c:11240                    (3126d4000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51455'
# SDK NOTICE Fri May 19 13:06:50.915 2023 solClient.c:11395                    (3126d4000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51455'
# Response Code: 0 | Event Code: 12 | Info: solClient.c:12194                    (3126d4000) Session '(c0,s1)_sinopac' keep-alive on tcp_TxRx detected session down, client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.6 | Event: Session reconnecting
# SDK NOTICE Fri May 19 13:06:53.119 2023 solClientOS.c:4470                   (3128e0000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:06:53.119 2023 solClient.c:6147                     (3128e0000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:06:53.119 2023 solClient.c:11240                    (3128e0000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51461'
# SDK NOTICE Fri May 19 13:06:53.119 2023 solClient.c:11395                    (3128e0000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51461'
# SDK NOTICE Fri May 19 13:06:53.968 2023 solClientOS.c:4470                   (3126d4000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:06:53.968 2023 solClient.c:6147                     (3126d4000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:06:53.968 2023 solClient.c:11240                    (3126d4000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51467'
# SDK NOTICE Fri May 19 13:06:53.968 2023 solClient.c:11395                    (3126d4000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51467'
# SDK NOTICE Fri May 19 13:06:56.151 2023 solClientOS.c:4470                   (3128e0000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:06:56.151 2023 solClient.c:6147                     (3128e0000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:06:56.151 2023 solClient.c:11240                    (3128e0000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51471'
# SDK NOTICE Fri May 19 13:06:56.151 2023 solClient.c:11395                    (3128e0000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51471'
# SDK NOTICE Fri May 19 13:24:19.643 2023 solClientOS.c:4470                   (3126d4000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:24:19.643 2023 solClient.c:6147                     (3126d4000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:24:19.643 2023 solClient.c:11240                    (3126d4000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51475'
# SDK NOTICE Fri May 19 13:24:19.643 2023 solClient.c:11395                    (3126d4000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51475'
# SDK NOTICE Fri May 19 13:24:21.843 2023 solClientOS.c:4470                   (3128e0000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:24:21.843 2023 solClient.c:6147                     (3128e0000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:24:21.844 2023 solClient.c:11240                    (3128e0000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51481'
# SDK NOTICE Fri May 19 13:24:21.844 2023 solClient.c:11395                    (3128e0000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51481'
# SDK NOTICE Fri May 19 13:24:22.668 2023 solClientOS.c:4470                   (3126d4000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:24:22.668 2023 solClient.c:6147                     (3126d4000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:24:22.669 2023 solClient.c:11240                    (3126d4000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51483'
# SDK NOTICE Fri May 19 13:24:22.669 2023 solClient.c:11395                    (3126d4000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51483'
# SDK NOTICE Fri May 19 13:24:24.868 2023 solClientOS.c:4470                   (3128e0000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:24:24.868 2023 solClient.c:6147                     (3128e0000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:24:24.868 2023 solClient.c:11240                    (3128e0000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51487'
# SDK NOTICE Fri May 19 13:24:24.868 2023 solClient.c:11395                    (3128e0000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51487'
# SDK NOTICE Fri May 19 13:24:25.709 2023 solClientOS.c:4470                   (3126d4000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:24:25.709 2023 solClient.c:6147                     (3126d4000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:24:25.709 2023 solClient.c:11240                    (3126d4000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51490'
# SDK NOTICE Fri May 19 13:24:25.709 2023 solClient.c:11395                    (3126d4000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51490'
# SDK NOTICE Fri May 19 13:24:27.922 2023 solClientOS.c:4470                   (3128e0000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:24:27.922 2023 solClient.c:6147                     (3128e0000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:24:27.922 2023 solClient.c:11240                    (3128e0000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51496'
# SDK NOTICE Fri May 19 13:24:27.922 2023 solClient.c:11395                    (3128e0000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51496'
# SDK NOTICE Fri May 19 13:24:28.800 2023 solClientOS.c:4470                   (3126d4000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:24:28.800 2023 solClient.c:6147                     (3126d4000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:24:28.800 2023 solClient.c:11240                    (3126d4000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51498'
# SDK NOTICE Fri May 19 13:24:28.800 2023 solClient.c:11395                    (3126d4000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51498'
# SDK NOTICE Fri May 19 13:39:32.635 2023 solClientOS.c:4470                   (3128e0000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:39:32.635 2023 solClient.c:6147                     (3128e0000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:39:32.635 2023 solClient.c:11240                    (3128e0000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51500'
# SDK NOTICE Fri May 19 13:39:32.635 2023 solClient.c:11395                    (3128e0000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51500'
# SDK NOTICE Fri May 19 13:39:33.541 2023 solClientOS.c:4470                   (3126d4000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:39:33.541 2023 solClient.c:6147                     (3126d4000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:39:33.542 2023 solClient.c:11240                    (3126d4000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51502'
# SDK NOTICE Fri May 19 13:39:33.542 2023 solClient.c:11395                    (3126d4000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51502'
# SDK NOTICE Fri May 19 13:39:35.731 2023 solClientOS.c:4470                   (3128e0000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:39:35.731 2023 solClient.c:6147                     (3128e0000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:39:35.731 2023 solClient.c:11240                    (3128e0000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51506'
# SDK NOTICE Fri May 19 13:39:35.731 2023 solClient.c:11395                    (3128e0000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51506'
# SDK NOTICE Fri May 19 13:39:36.607 2023 solClientOS.c:4470                   (3126d4000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:39:36.607 2023 solClient.c:6147                     (3126d4000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:39:36.607 2023 solClient.c:11240                    (3126d4000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51508'
# SDK NOTICE Fri May 19 13:39:36.607 2023 solClient.c:11395                    (3126d4000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51508'
# SDK NOTICE Fri May 19 13:39:38.735 2023 solClientOS.c:4470                   (3128e0000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:39:38.735 2023 solClient.c:6147                     (3128e0000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:39:38.735 2023 solClient.c:11240                    (3128e0000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51512'
# SDK NOTICE Fri May 19 13:39:38.735 2023 solClient.c:11395                    (3128e0000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51512'
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /var/folders/59/8_41z4690f73xl4p8mhyh_z00000gn/T/ipykernel_14360/3470094407.py in <module>
#      17     if(datetime.datetime.now() >= ts):
#      18
# ---> 19         kbars = api.kbars(
#      20             contract=api.Contracts.Futures.TXF.TXFR1,
#      21             start=datetime.date.today().strftime("%Y-%m-%d"),
#
# ~/opt/anaconda3/lib/python3.9/site-packages/shioaji/shioaji.py in kbars(self, contract, start, end, timeout, cb)
#     844             end (str): "2020-06-02"
#     845         """
# --> 846         kbars = self._solace.kbars(contract, start, end, timeout, cb)
#     847         return kbars
#     848
#
# shioaji/backend/solace/api.pyx in shioaji.backend.solace.api.SolaceAPI.kbars()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pysolace/__init__.py in request(self, topic, payload, corrid, timeout, cos, format, cb)
#     276             self.rep_callback_map.pop(corrid, None)
#     277             if not recv.wait(timeout / 1000):
# --> 278                 raise TimeoutError(
#     279                     "Topic: {}, Corr: {}, Client: {}, payload: {}".format(
#     280                         topic, corrid, self._client_name, payload
#
# TimeoutError: Topic: api/v1/data/kbars, Corr: c10, Client: PYAPI/A131461990/0519/044944/845138/42.73.61.243, payload: {'token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..RkMXDC58QnThskDOxtqUdnE2kuGyq_lgF-HI_qySbRk', 'contract': {'security_type': 'FUT', 'exchange': 'TAIFEX', 'code': 'TXFR1', 'symbol': 'TXFR1', 'name': '臺股期貨近月', 'category': 'TXF', 'currency': 'TWD', 'delivery_month': '202306', 'delivery_date': '2023/06/21', 'strike_price': 0, 'option_right': '', 'underlying_kind': 'I', 'underlying_code': '', 'unit': 1, 'multiplier': 0, 'limit_up': 17675.0, 'limit_down': 14463.0, 'reference': 16069.0, 'update_date': '2023/05/19', 'margin_trading_balance': 0, 'short_selling_balance': 0, 'day_trade': 'No', 'target_code': 'TXFF3'}, 'start': '2023-05-19', 'end': '2023-05-19'}
# SDK NOTICE Fri May 19 13:39:39.659 2023 solClientOS.c:4470                   (3126d4000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:39:39.659 2023 solClient.c:6147                     (3126d4000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:39:39.659 2023 solClient.c:11240                    (3126d4000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51514'
# SDK NOTICE Fri May 19 13:39:39.659 2023 solClient.c:11395                    (3126d4000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51514'
# SDK NOTICE Fri May 19 13:39:41.789 2023 solClientOS.c:4470                   (3128e0000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:39:41.790 2023 solClient.c:6147                     (3128e0000) Session '(c1,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:39:41.790 2023 solClient.c:11240                    (3128e0000) Session '(c1,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51515'
# SDK NOTICE Fri May 19 13:39:41.790 2023 solClient.c:11395                    (3128e0000) Protocol or communication error when attempting to login for session '(c1,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044946/813567/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51515'
# Session Down.
# Response Code: 0 | Event Code: 1 | Info: solClientOS.c:4470                   (3128e0000) TCP connection failure for fd 84, error = Network is unreachable (51) | Event: Session down
# SDK NOTICE Fri May 19 13:39:42.714 2023 solClientOS.c:4470                   (3126d4000) TCP connection failure for fd 84, error = Network is unreachable (51)
# SDK NOTICE Fri May 19 13:39:42.714 2023 solClient.c:6147                     (3126d4000) Session '(c0,s1)_sinopac', could not open transport for tcp_TxRx
# SDK NOTICE Fri May 19 13:39:42.714 2023 solClient.c:11240                    (3126d4000) Session '(c0,s1)_sinopac' error attempting transport connection, client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51516'
# SDK NOTICE Fri May 19 13:39:42.714 2023 solClient.c:11395                    (3126d4000) Protocol or communication error when attempting to login for session '(c0,s1)_sinopac'; are session HOST and PORT correct? client name 'PYAPI/A131461990/0519/044944/845138/42.73.61.243', VPN name 'sinopac', peer address 'hostname '203.66.91.161:80' IP 203.66.91.161:80', connection 'tcp_TxRx' local address 'IP 0.0.0.0:51516'
# Session Down.
# Response Code: 0 | Event Code: 1 | Info: solClientOS.c:4470                   (3126d4000) TCP connection failure for fd 84, error = Network is unreachable (51) | Event: Session down
